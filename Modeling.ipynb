# %%
import numpy as np
import tensorflow as tf

# %%
npz = np.load('Autism_data_train.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('Autism_validation.npz')

validation_inputs = npz['inputs'].astype(np.float)
validation_targets = npz['targets'].astype(np.int)

npz = np.load('Autism_test.npz')

test_inputs = npz['inputs'].astype(np.float)
test_targets = npz['targets'].astype(np.int)

# %%
import matplotlib.pyplot as plt
input_size = 15
output_size = 2
hidden_layer_size = 80

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')    
])

model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 200
max_epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 1)

history = model.fit(train_inputs , train_targets,
         batch_size = batch_size,
         epochs = max_epochs,
         callbacks = [early_stopping],
         validation_data=(validation_inputs,validation_targets),
         verbose = 2)
# Out:
# Epoch 1/100
# 5/5 - 0s - loss: 0.7115 - accuracy: 0.5267 - val_loss: 0.5614 - val_accuracy: 0.8190
# Epoch 2/100
# 5/5 - 0s - loss: 0.5227 - accuracy: 0.8149 - val_loss: 0.4269 - val_accuracy: 0.8857
# Epoch 3/100
# 5/5 - 0s - loss: 0.3979 - accuracy: 0.8671 - val_loss: 0.3308 - val_accuracy: 0.8952
# Epoch 4/100
# 5/5 - 0s - loss: 0.3063 - accuracy: 0.9122 - val_loss: 0.2577 - val_accuracy: 0.9524
# Epoch 5/100
# 5/5 - 0s - loss: 0.2367 - accuracy: 0.9431 - val_loss: 0.2045 - val_accuracy: 0.9524
# Epoch 6/100
# 5/5 - 0s - loss: 0.1867 - accuracy: 0.9644 - val_loss: 0.1693 - val_accuracy: 0.9524
# Epoch 7/100
# 5/5 - 0s - loss: 0.1509 - accuracy: 0.9798 - val_loss: 0.1436 - val_accuracy: 0.9524
# Epoch 8/100
# 5/5 - 0s - loss: 0.1240 - accuracy: 0.9881 - val_loss: 0.1226 - val_accuracy: 0.9619
# Epoch 9/100
# 5/5 - 0s - loss: 0.1028 - accuracy: 0.9893 - val_loss: 0.1038 - val_accuracy: 0.9619
# Epoch 10/100
# 5/5 - 0s - loss: 0.0872 - accuracy: 0.9941 - val_loss: 0.0906 - val_accuracy: 0.9810
# Epoch 11/100
# 5/5 - 0s - loss: 0.0757 - accuracy: 0.9941 - val_loss: 0.0808 - val_accuracy: 0.9810
# Epoch 12/100
# 5/5 - 0s - loss: 0.0658 - accuracy: 0.9976 - val_loss: 0.0756 - val_accuracy: 0.9810
# Epoch 13/100
# 5/5 - 0s - loss: 0.0582 - accuracy: 0.9976 - val_loss: 0.0735 - val_accuracy: 0.9810
# Epoch 14/100
# 5/5 - 0s - loss: 0.0513 - accuracy: 0.9988 - val_loss: 0.0696 - val_accuracy: 0.9810
# Epoch 15/100
# 5/5 - 0s - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9810
# Epoch 16/100
# 5/5 - 0s - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.0592 - val_accuracy: 0.9905
# Epoch 17/100
# 5/5 - 0s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9905
# Epoch 18/100
# 5/5 - 0s - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.0529 - val_accuracy: 0.9905
# Epoch 19/100
# 5/5 - 0s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9905
# Epoch 20/100
# 5/5 - 0s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9905
# Epoch 21/100
# 5/5 - 0s - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 0.9905
# Epoch 22/100
# 5/5 - 0s - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0449 - val_accuracy: 0.9905
# Epoch 23/100
# 5/5 - 0s - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9905
# Epoch 24/100
# 5/5 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9905
# Epoch 25/100
# 5/5 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0418 - val_accuracy: 0.9905
# Epoch 26/100
# 5/5 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0401 - val_accuracy: 0.9905
# Epoch 27/100
# 5/5 - 0s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.0385 - val_accuracy: 0.9905
# Epoch 28/100
# 5/5 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 0.9905
# Epoch 29/100
# 5/5 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 0.9905
# Epoch 30/100
# 5/5 - 0s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 0.9905
# Epoch 31/100
# 5/5 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0352 - val_accuracy: 0.9905
# Epoch 32/100
# 5/5 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.9905
# Epoch 33/100
# 5/5 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0327 - val_accuracy: 0.9905
# Epoch 34/100
# 5/5 - 0s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9905
# Epoch 35/100
# 5/5 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9905
# Epoch 36/100
# 5/5 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9905
# Epoch 37/100
# 5/5 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9905
# Epoch 38/100
# 5/5 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9905
# Epoch 39/100
# 5/5 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9905
# Epoch 40/100
# 5/5 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 0.9905
# Epoch 41/100
# 5/5 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0276 - val_accuracy: 0.9905
# Epoch 42/100
# 5/5 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0273 - val_accuracy: 0.9905
# Epoch 43/100
# 5/5 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0270 - val_accuracy: 0.9905
# Epoch 44/100
# 5/5 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9905
# Epoch 45/100
# 5/5 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0263 - val_accuracy: 0.9905
# Epoch 46/100
# 5/5 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0259 - val_accuracy: 0.9905
# Epoch 47/100
# 5/5 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0253 - val_accuracy: 0.9905
# Epoch 48/100
# 5/5 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0249 - val_accuracy: 0.9905
# Epoch 49/100
# 5/5 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0248 - val_accuracy: 0.9905
# Epoch 50/100
# 5/5 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9905
# Epoch 51/100
# 5/5 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0243 - val_accuracy: 0.9905
# Epoch 52/100
# 5/5 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 0.9905
# Epoch 53/100
# 5/5 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0239 - val_accuracy: 0.9905
# Epoch 54/100
# 5/5 - 0s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9905
# Epoch 55/100
# 5/5 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0235 - val_accuracy: 0.9905
# Epoch 56/100
# 5/5 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9905
# Epoch 57/100
# 5/5 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 0.9905
# Epoch 58/100
# 5/5 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 0.9905
# Epoch 59/100
# 5/5 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0219 - val_accuracy: 0.9905
# Epoch 60/100
# 5/5 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 0.9905
# Epoch 61/100
# 5/5 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9905
# Epoch 62/100
# 5/5 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9905
# Epoch 63/100
# 5/5 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9905
# Epoch 64/100
# 5/5 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0211 - val_accuracy: 0.9905
# Epoch 65/100
# 5/5 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 0.9905
# Epoch 66/100
# 5/5 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0208 - val_accuracy: 0.9905
# Epoch 67/100
# 5/5 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 0.9905
# Epoch 68/100
# 5/5 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0202 - val_accuracy: 0.9905
# Epoch 69/100
# 5/5 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 0.9905
# Epoch 70/100
# 5/5 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0199 - val_accuracy: 0.9905
# Epoch 71/100
# 5/5 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9905
# Epoch 72/100
# 5/5 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 0.9905
# Epoch 73/100
# 5/5 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 0.9905
# Epoch 74/100
# 5/5 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9905
# Epoch 75/100
# 5/5 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 0.9905
# Epoch 76/100
# 5/5 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9905
# Epoch 77/100
# 5/5 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9905
# Epoch 78/100
# 5/5 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9905
# Epoch 79/100
# 5/5 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9905
# Epoch 80/100
# 5/5 - 0s - loss: 9.8381e-04 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 0.9905
# Epoch 81/100
# 5/5 - 0s - loss: 9.5396e-04 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9905
# Epoch 82/100
# 5/5 - 0s - loss: 9.2580e-04 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9905
# Epoch 83/100
# 5/5 - 0s - loss: 8.9985e-04 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9905
# Epoch 84/100
# 5/5 - 0s - loss: 8.7629e-04 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9905
# Epoch 85/100
# 5/5 - 0s - loss: 8.4779e-04 - accuracy: 1.0000 - val_loss: 0.0178 - val_accuracy: 0.9905
# Epoch 86/100
# 5/5 - 0s - loss: 8.2609e-04 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9905
# Epoch 87/100
# 5/5 - 0s - loss: 8.0353e-04 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9905
# Epoch 88/100
# 5/5 - 0s - loss: 7.8276e-04 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9905
# Epoch 89/100
# 5/5 - 0s - loss: 7.5986e-04 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 0.9905
# Epoch 90/100
# 5/5 - 0s - loss: 7.4091e-04 - accuracy: 1.0000 - val_loss: 0.0174 - val_accuracy: 0.9905
# Epoch 91/100
# 5/5 - 0s - loss: 7.2029e-04 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9905
# Epoch 92/100
# 5/5 - 0s - loss: 7.0254e-04 - accuracy: 1.0000 - val_loss: 0.0172 - val_accuracy: 0.9905
# Epoch 93/100
# 5/5 - 0s - loss: 6.8503e-04 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9905
# Epoch 94/100
# 5/5 - 0s - loss: 6.6768e-04 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9905
# Epoch 95/100
# 5/5 - 0s - loss: 6.5241e-04 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 0.9905
# Epoch 96/100
# 5/5 - 0s - loss: 6.3803e-04 - accuracy: 1.0000 - val_loss: 0.0168 - val_accuracy: 0.9905
# Epoch 97/100
# 5/5 - 0s - loss: 6.2276e-04 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 0.9905
# Epoch 98/100
# 5/5 - 0s - loss: 6.0765e-04 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9905
# Epoch 99/100
# 5/5 - 0s - loss: 5.9379e-04 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9905
# Epoch 100/100
# 5/5 - 0s - loss: 5.8089e-04 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 0.9905

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_inputs,test_targets)
# Out:
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
